# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
gray_array = np.array(Image.open("202410210600.png").convert('L'))
bin_map = (gray_array > 0).astype(np.uint8)
plt.imshow(bin_map)
